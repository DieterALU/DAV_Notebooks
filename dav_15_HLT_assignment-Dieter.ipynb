# %% [markdown]
# # <font color='maroon'>Assessment</font>
# Given the following dataset, answer the questions that follow. The necessary libraries have been imported.

# %%
import matplotlib.pyplot as plt
from numpy import arange
import scipy.stats as stats
import pandas as pd
import seaborn as sns
import random as rnd

# %%
# %matplotlib inline

# %% [markdown]
# ### Low Memory Error
# Need to run the low_memory command as the csv file is large with unstructured data

# %%
data = pd.read_csv('athletes.csv', sep=',', low_memory=False)

# %% [markdown]
# ### Question 1
# Study the data. What is the size of the dataset?

# %%
data
# Out:
#         athlete_id               name               region  \
# 0           2554.0          Pj Ablang           South West
# 1           3517.0      Derek Abdella                  NaN
# 2           4691.0                NaN                  NaN
# 3           5164.0        Abo Brandon  Southern California
# 4           5286.0        Bryce Abbey                  NaN
# 5           6491.0        Jason Abney                  NaN
# 6           6610.0      Anthony Abeel        South Central
# 7           7268.0                NaN                  NaN
# 8           7463.0          Tye Abell                  NaN
# 9           8242.0      Ryan Achilles                  NaN
# 10         10890.0       Damian Abson                  NaN
# 11         11003.0                NaN                  NaN
# 12         11416.0      Mike Abgarian                  NaN
# 13         13285.0        Kipp Abbott         Central East
# 14         13576.0     Mikko Aaltonen               Europe
# 15         14073.0    Ignacio Abascal                  NaN
# 16         15223.0         Dan Abbett                  NaN
# 17         16068.0          Allan Abt                  NaN
# 18         17658.0        Ryan Abbott         Central East
# 19         17745.0                NaN                  NaN
# 20         21053.0      Douglas Acker           North East
# 21         21269.0       Erik Acevedo  Southern California
# 22         21685.0     Richard Ablett               Africa
# 23         21747.0         ariel abal                  NaN
# 24         22217.0                NaN                  NaN
# 25         22344.0       Joji Abasolo                  NaN
# 26         24013.0       Peter Abreut           South East
# 27         25464.0        Joe Abruzzo           North East
# 28         26016.0        Noah Abbott           North East
# 29         26612.0                NaN                  NaN
# ...            ...                ...                  ...
# 422976    462885.0      Carrie Garber        North Central
# 422977    593552.0     Olga Aroniadis           North East
# 422978    492453.0  Isabelle Oliveira        Latin America
# 422979    599916.0    Teletha Leonard        North Central
# 422980    508515.0     Roquia Darwish               Africa
# 422981    604551.0            Amy Yin  Southern California
# 422982    518427.0         Sadaf Mian           North East
# 422983    611187.0       Sondra Parra           South East
# 422984    539304.0       Erin O'Brien           North East
# 422985    618087.0   Jodie-May Turner            Australia
# 422986    553835.0   Veronica Stueber        North Central
# 422987    625949.0      Gerry Saucedo  Southern California
# 422988    563600.0      Shiela Fetzer           South West
# 422989    628990.0    Sarah de Tuboly  Northern California
# 422990    575864.0      Megan Sanders        South Central
# 422991    412885.0     Helena Vissing  Southern California
# 422992    602161.0     Elizabeth Ruiz        North Central
# 422993    471129.0     Mariana Zavati        Latin America
# 422994    617058.0         Nakia Tull           North East
# 422995    504437.0    Joanna Hamilton        North Central
# 422996    631665.0          April Lee        South Central
# 422997    514232.0           Fatma Ak               Africa
# 422998    519228.0    Carmel Hallinan            Australia
# 422999    539888.0        Perla Perez           South East
# 423000    561571.0        Nely Medina        Latin America
# 423001    574489.0         Odo Renata        Latin America
# 423002    585696.0      Lozzie Trevor            Australia
# 423003    608828.0      Marisol Smith           North West
# 423004    628881.0    Pedrini Morgane               Europe
# 423005    631847.0         Eden Kenny  Northern California
#
#                                   team                        affiliate  \
# 0                          Double Edge             Double Edge CrossFit
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                         LAX CrossFit                     LAX CrossFit
# 4                                  NaN                              NaN
# 5                                  NaN                              NaN
# 6                           Get Lifted              Get Lifted CrossFit
# 7                                  NaN                              NaN
# 8                                  NaN                              NaN
# 9                                  NaN                              NaN
# 10                                 NaN                              NaN
# 11                                 NaN                              NaN
# 12                                 NaN                              NaN
# 13                            Fit Club                     CrossFit 614
# 14               Reebok CrossFit 33100            Reebok CrossFit 33100
# 15                                 NaN                              NaN
# 16                                 NaN                              NaN
# 17                                 NaN                              NaN
# 18                New Species CrossFit             CrossFit New Species
# 19                                 NaN                              NaN
# 20             CrossFit South Shore LI        Crossfit South Shore L.I.
# 21              CrossFit Training Yard           CrossFit Training Yard
# 22              Cape CrossFit Wolfpack                    Cape CrossFit
# 23                                 NaN                              NaN
# 24                                 NaN                              NaN
# 25                                 NaN                              NaN
# 26              En Fuego FireBreathers                CrossFit En Fuego
# 27                    CrossFit Rapture                 CrossFit Rapture
# 28             CrossFit South Brooklyn          CrossFit South Brooklyn
# 29                                 NaN                              NaN
# ...                                ...                              ...
# 422976                             NaN              CrossFit Slipstream
# 422977                             NaN              Cow Harbor CrossFit
# 422978                             NaN                Vittoria CrossFit
# 422979                             NaN        West Little Rock CrossFit
# 422980                    CPCF Salmiya  Circuit Plus CrossFit Gulf Road
# 422981                             NaN              District 7 CrossFit
# 422982  Reebok CrossFit 5th Ave Ninjas          CrossFit Reebok 5th Ave
# 422983                             NaN                 CrossFit Militia
# 422984                   CF 781 Beasts                     CrossFit 781
# 422985                             NaN                              NaN
# 422986                             NaN                 CrossFit Oshkosh
# 422987                             NaN               CrossFit Camarillo
# 422988                         The DRC                Dead Red CrossFit
# 422989                             NaN                     CrossFit EGA
# 422990             CrossFit Waxahachie              CrossFit Waxahachie
# 422991                             NaN               CrossFit High Five
# 422992                 CrossFit Marion                  CrossFit Marion
# 422993                             NaN              CrossFit Big Jungle
# 422994                    CFNE Courage             CrossFit New England
# 422995                    FTX CrossFit                     FTX CrossFit
# 422996                             NaN                     CrossFit 290
# 422997                    CPCF Salmiya  Circuit Plus CrossFit Gulf Road
# 422998               CrossFit Maitland                CrossFit Maitland
# 422999     Reebok CrossFit Miami Beach      Reebok CrossFit Miami Beach
# 423000                             NaN             Go Fighters CrossFit
# 423001               Team Guarujá Inox                 CrossFit Guaruja
# 423002         FBP CrossFit Games Team                     FBP CrossFit
# 423003             CrossFit Oak Harbor              CrossFit Oak Harbor
# 423004                             NaN                      CrossFit 67
# 423005                             NaN            Contra Costa CrossFit
#
#         gender   age  height  weight   fran         ...           deadlift  \
# 0         Male  24.0    70.0   166.0    NaN         ...              400.0
# 1         Male  42.0    70.0   190.0    NaN         ...                NaN
# 2          NaN   NaN     NaN     NaN    NaN         ...                NaN
# 3         Male  40.0    67.0     NaN  211.0         ...              375.0
# 4         Male  32.0    65.0   149.0  206.0         ...                NaN
# 5         Male  37.0    73.0   230.0    NaN         ...              435.0
# 6         Male  21.0    72.0   175.0    NaN         ...                0.0
# 7          NaN   NaN     NaN     NaN    NaN         ...                NaN
# 8         Male  30.0    72.0   175.0    NaN         ...                0.0
# 9         Male  40.0    68.0   177.0  205.0         ...              365.0
# 10        Male  42.0    69.0   214.0    NaN         ...              507.0
# 11         NaN   NaN     NaN     NaN    NaN         ...                NaN
# 12        Male  31.0    65.0   150.0  119.0         ...              465.0
# 13        Male  43.0    71.0   185.0    NaN         ...                0.0
# 14        Male  37.0     NaN     NaN    NaN         ...                NaN
# 15        Male  23.0    72.0   165.0    NaN         ...              419.0
# 16        Male  43.0    66.0   175.0  304.0         ...                NaN
# 17        Male  27.0    74.0   187.0    NaN         ...                NaN
# 18        Male  30.0    70.0   155.0    NaN         ...              335.0
# 19         NaN   NaN     NaN     NaN    NaN         ...                NaN
# 20        Male  42.0    72.0   210.0  198.0         ...              515.0
# 21        Male  30.0    71.0   200.0  243.0         ...              385.0
# 22        Male  28.0    70.0   176.0  720.0         ...              335.0
# 23        Male  43.0    70.0   198.0  384.0         ...              385.0
# 24         NaN   NaN     NaN     NaN    NaN         ...                NaN
# 25        Male  39.0    66.0   158.0    NaN         ...              385.0
# 26        Male  35.0     NaN     NaN    NaN         ...                NaN
# 27        Male  35.0    68.0   225.0  215.0         ...              440.0
# 28        Male  32.0     NaN     NaN    NaN         ...                NaN
# 29         NaN   NaN     NaN     NaN    NaN         ...                NaN
# ...        ...   ...     ...     ...    ...         ...                ...
# 422976  Female  39.0     NaN     NaN    NaN         ...                NaN
# 422977  Female  34.0     NaN     NaN    NaN         ...                NaN
# 422978  Female  18.0     NaN   137.0    NaN         ...                NaN
# 422979  Female  46.0     NaN     NaN    NaN         ...                NaN
# 422980  Female  31.0     NaN     NaN    NaN         ...                NaN
# 422981  Female  30.0    60.0   118.0    NaN         ...                NaN
# 422982  Female  33.0    62.0   138.0    NaN         ...                NaN
# 422983  Female  34.0     NaN   139.0    NaN         ...                NaN
# 422984  Female  29.0     NaN     NaN    NaN         ...                NaN
# 422985  Female  49.0     NaN     NaN    NaN         ...                NaN
# 422986  Female  34.0     NaN     NaN    NaN         ...                NaN
# 422987  Female  49.0     NaN   200.0    NaN         ...                NaN
# 422988  Female  34.0    65.0   234.0    NaN         ...                NaN
# 422989  Female  26.0     NaN     NaN    NaN         ...                NaN
# 422990  Female  31.0     NaN     NaN    NaN         ...                NaN
# 422991  Female  31.0     NaN     NaN    NaN         ...                NaN
# 422992  Female  34.0     NaN     NaN    NaN         ...                NaN
# 422993  Female  22.0     NaN     NaN    NaN         ...                NaN
# 422994  Female  30.0     NaN     NaN    NaN         ...                NaN
# 422995  Female  36.0     NaN     NaN    NaN         ...                NaN
# 422996  Female  29.0     NaN     NaN    NaN         ...                NaN
# 422997  Female  25.0    65.0   128.0    NaN         ...                NaN
# 422998  Female  35.0     NaN     NaN    NaN         ...                NaN
# 422999  Female  19.0     NaN     NaN    NaN         ...                NaN
# 423000  Female  24.0     NaN   155.0    NaN         ...                NaN
# 423001  Female  36.0     NaN     NaN    NaN         ...                NaN
# 423002  Female  27.0     NaN     NaN    NaN         ...                NaN
# 423003  Female  44.0     NaN     NaN    NaN         ...                NaN
# 423004  Female  20.0    64.0    61.0    NaN         ...               80.0
# 423005  Female  26.0     NaN     NaN    NaN         ...                NaN
#
#         backsq  pullups                                                eat  \
# 0        305.0      NaN                                                NaN
# 1          NaN      NaN                                                NaN
# 2          NaN      NaN                                                NaN
# 3        325.0     25.0               I eat 1-3 full cheat meals per week|
# 4        325.0     50.0  I eat quality foods but don't measure the amount|
# 5        414.0      NaN                                I eat strict Paleo|
# 6          0.0      0.0  I eat quality foods but don't measure the amou...
# 7          NaN      NaN                                                NaN
# 8          0.0      0.0                                                NaN
# 9        365.0      NaN  I eat quality foods but don't measure the amount|
# 10       364.0      NaN                                                NaN
# 11         NaN      NaN                                                NaN
# 12       405.0     81.0  I eat quality foods but don't measure the amou...
# 13         0.0      0.0  I eat quality foods but don't measure the amount|
# 14         NaN      NaN                                                NaN
# 15         0.0     55.0  I eat quality foods but don't measure the amount|
# 16         NaN      NaN  I eat quality foods but don't measure the amount|
# 17         NaN      NaN  I eat quality foods but don't measure the amount|
# 18       235.0      NaN                                                NaN
# 19         NaN      NaN                                                NaN
# 20       505.0      NaN  I eat quality foods but don't measure the amount|
# 21       315.0     35.0                      I eat whatever is convenient|
# 22       254.0     27.0               I eat 1-3 full cheat meals per week|
# 23         NaN     22.0                                                NaN
# 24         NaN      NaN                                                NaN
# 25       285.0     31.0  I eat strict Paleo|I eat quality foods but don...
# 26         NaN      NaN                                                NaN
# 27       405.0     24.0  I eat quality foods but don't measure the amount|
# 28         NaN      NaN                                                NaN
# 29         NaN      NaN                                                NaN
# ...        ...      ...                                                ...
# 422976     NaN      NaN                                                NaN
# 422977     NaN      NaN                                                NaN
# 422978     NaN      NaN                                                NaN
# 422979     NaN      NaN                                                NaN
# 422980     NaN      NaN                                                NaN
# 422981     NaN      NaN  I weigh and measure my food|I eat quality food...
# 422982     NaN      NaN                                                NaN
# 422983     NaN      NaN                                                NaN
# 422984     NaN      NaN                                                NaN
# 422985     NaN      NaN                                                NaN
# 422986     NaN      NaN                                                NaN
# 422987     NaN      NaN                                                NaN
# 422988     NaN      NaN                                                NaN
# 422989     NaN      NaN                                                NaN
# 422990     NaN      NaN                                                NaN
# 422991     NaN      NaN                                                NaN
# 422992     NaN      NaN                                                NaN
# 422993     NaN      NaN                                                NaN
# 422994     NaN      NaN                                                NaN
# 422995     NaN      NaN                                                NaN
# 422996     NaN      NaN                                                NaN
# 422997     NaN      NaN                                                NaN
# 422998     NaN      NaN                                                NaN
# 422999     NaN      NaN                                                NaN
# 423000     NaN      NaN                                                NaN
# 423001     NaN      NaN                                                NaN
# 423002     NaN      NaN                                                NaN
# 423003     NaN      NaN                                                NaN
# 423004   143.0      NaN  I eat quality foods but don't measure the amount|
# 423005     NaN      NaN                                                NaN
#
#                                                     train  \
# 0       I workout mostly at a CrossFit Affiliate|I hav...
# 1       I have a coach who determines my programming|I...
# 2                                                     NaN
# 3       I workout mostly at a CrossFit Affiliate|I hav...
# 4       I workout mostly at a CrossFit Affiliate|I inc...
# 5       I workout mostly at a CrossFit Affiliate|I rec...
# 6       I workout mostly at a CrossFit Affiliate|I hav...
# 7                                                     NaN
# 8                                                     NaN
# 9       I workout mostly at a CrossFit Affiliate|I rec...
# 10                                                    NaN
# 11                                                    NaN
# 12      I workout mostly at a CrossFit Affiliate|I wri...
# 13              I workout mostly at a CrossFit Affiliate|
# 14                                                    NaN
# 15      I workout mostly at a CrossFit Affiliate|I inc...
# 16              I workout mostly at a CrossFit Affiliate|
# 17              I workout mostly at a CrossFit Affiliate|
# 18                                                    NaN
# 19                                                    NaN
# 20      I workout mostly at a CrossFit Affiliate|I wri...
# 21      I workout mostly at a CrossFit Affiliate|I inc...
# 22              I workout mostly at a CrossFit Affiliate|
# 23                                                    NaN
# 24                                                    NaN
# 25              I workout mostly at a CrossFit Affiliate|
# 26                                                    NaN
# 27      I workout mostly at a CrossFit Affiliate|I rec...
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 422976                                                NaN
# 422977                                                NaN
# 422978                                                NaN
# 422979                                                NaN
# 422980                                                NaN
# 422981          I workout mostly at a CrossFit Affiliate|
# 422982          I workout mostly at a CrossFit Affiliate|
# 422983                                                NaN
# 422984                                                NaN
# 422985                                                NaN
# 422986                                                NaN
# 422987                                                NaN
# 422988                                                NaN
# 422989                                                NaN
# 422990                                                NaN
# 422991                                                NaN
# 422992                                                NaN
# 422993                                                NaN
# 422994                                                NaN
# 422995                                                NaN
# 422996                                                NaN
# 422997                                                NaN
# 422998                                                NaN
# 422999                                                NaN
# 423000                                                NaN
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004          I workout mostly at a CrossFit Affiliate|
# 423005                                                NaN
#
#                                                background  \
# 0       I played youth or high school level sports|I r...
# 1             I played youth or high school level sports|
# 2                                                     NaN
# 3             I played youth or high school level sports|
# 4                                I played college sports|
# 5             I played youth or high school level sports|
# 6         I have no athletic background besides CrossFit|
# 7                                                     NaN
# 8                                                     NaN
# 9       I played youth or high school level sports|I p...
# 10                                                    NaN
# 11                                                    NaN
# 12      I played youth or high school level sports|I p...
# 13        I have no athletic background besides CrossFit|
# 14                                                    NaN
# 15      I played youth or high school level sports|I p...
# 16            I played youth or high school level sports|
# 17                  I regularly play recreational sports|
# 18                                                    NaN
# 19                                                    NaN
# 20            I played youth or high school level sports|
# 21      I played youth or high school level sports|I p...
# 22        I have no athletic background besides CrossFit|
# 23                                                    NaN
# 24                                                    NaN
# 25            I played youth or high school level sports|
# 26                                                    NaN
# 27            I played youth or high school level sports|
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 422976                                                NaN
# 422977                                                NaN
# 422978                                                NaN
# 422979                                                NaN
# 422980                                                NaN
# 422981        I played youth or high school level sports|
# 422982    I have no athletic background besides CrossFit|
# 422983                                                NaN
# 422984                                                NaN
# 422985                                                NaN
# 422986                                                NaN
# 422987                                                NaN
# 422988                                                NaN
# 422989                                                NaN
# 422990                                                NaN
# 422991                                                NaN
# 422992                                                NaN
# 422993                                                NaN
# 422994                                                NaN
# 422995                                                NaN
# 422996                                                NaN
# 422997                                                NaN
# 422998                                                NaN
# 422999                                                NaN
# 423000                                                NaN
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004                                                NaN
# 423005                                                NaN
#
#                                                experience  \
# 0       I began CrossFit with a coach (e.g. at an affi...
# 1       I began CrossFit with a coach (e.g. at an affi...
# 2                                                     NaN
# 3       I began CrossFit by trying it alone (without a...
# 4       I began CrossFit by trying it alone (without a...
# 5       I began CrossFit by trying it alone (without a...
# 6       I began CrossFit with a coach (e.g. at an affi...
# 7                                                     NaN
# 8                                                     NaN
# 9       I began CrossFit by trying it alone (without a...
# 10                                                    NaN
# 11                                                    NaN
# 12      I began CrossFit by trying it alone (without a...
# 13      I began CrossFit with a coach (e.g. at an affi...
# 14                                                    NaN
# 15      I began CrossFit with a coach (e.g. at an affi...
# 16      I began CrossFit with a coach (e.g. at an affi...
# 17      I began CrossFit with a coach (e.g. at an affi...
# 18                                                    NaN
# 19                                                    NaN
# 20      I began CrossFit with a coach (e.g. at an affi...
# 21      I began CrossFit by trying it alone (without a...
# 22      I began CrossFit with a coach (e.g. at an affi...
# 23                                                    NaN
# 24                                                    NaN
# 25      I began CrossFit with a coach (e.g. at an affi...
# 26                                                    NaN
# 27      I began CrossFit with a coach (e.g. at an affi...
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 422976                                                NaN
# 422977                                                NaN
# 422978                                                NaN
# 422979                                                NaN
# 422980                                                NaN
# 422981  I began CrossFit with a coach (e.g. at an affi...
# 422982                                                NaN
# 422983                                                NaN
# 422984                                                NaN
# 422985                                                NaN
# 422986                                                NaN
# 422987                                                NaN
# 422988                                                NaN
# 422989                                                NaN
# 422990                                                NaN
# 422991                                                NaN
# 422992                                                NaN
# 422993                                                NaN
# 422994                                                NaN
# 422995                                                NaN
# 422996                                                NaN
# 422997                                                NaN
# 422998                                                NaN
# 422999                                                NaN
# 423000                                                NaN
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004  I began CrossFit with a coach (e.g. at an affi...
# 423005                                                NaN
#
#                                                  schedule  \
# 0              I do multiple workouts in a day 2x a week|
# 1              I do multiple workouts in a day 2x a week|
# 2                                                     NaN
# 3                      I usually only do 1 workout a day|
# 4       I usually only do 1 workout a day|I strictly s...
# 5       I usually only do 1 workout a day|I typically ...
# 6       I do multiple workouts in a day 3+ times a wee...
# 7                                                     NaN
# 8                                                     NaN
# 9       I usually only do 1 workout a day|I typically ...
# 10                                                    NaN
# 11                                                    NaN
# 12       I do multiple workouts in a day 3+ times a week|
# 13      I usually only do 1 workout a day|I typically ...
# 14                                                    NaN
# 15      I usually only do 1 workout a day|I do multipl...
# 16      I usually only do 1 workout a day|I typically ...
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21      I do multiple workouts in a day 1x a week|I ty...
# 22             I do multiple workouts in a day 1x a week|
# 23                                                    NaN
# 24                                                    NaN
# 25       I do multiple workouts in a day 3+ times a week|
# 26                                                    NaN
# 27             I typically rest 4 or more days per month|
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 422976                                                NaN
# 422977                                                NaN
# 422978                                                NaN
# 422979                                                NaN
# 422980                                                NaN
# 422981                 I usually only do 1 workout a day|
# 422982                                                NaN
# 422983                                                NaN
# 422984                                                NaN
# 422985                                                NaN
# 422986                                                NaN
# 422987                                                NaN
# 422988                                                NaN
# 422989                                                NaN
# 422990                                                NaN
# 422991                                                NaN
# 422992                                                NaN
# 422993                                                NaN
# 422994                                                NaN
# 422995                                                NaN
# 422996                                                NaN
# 422997                                                NaN
# 422998                                                NaN
# 422999                                                NaN
# 423000                                                NaN
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004  I usually only do 1 workout a day|I strictly s...
# 423005                                                NaN
#
#                     howlong   retrieved_datetime
# 0                 4+ years|                  NaN
# 1                 4+ years|                  NaN
# 2                       NaN                  NaN
# 3                 4+ years|                  NaN
# 4                1-2 years|                  NaN
# 5                 4+ years|                  NaN
# 6                2-4 years|                  NaN
# 7                       NaN                  NaN
# 8                       NaN                  NaN
# 9                2-4 years|                  NaN
# 10                      NaN                  NaN
# 11                      NaN                  NaN
# 12               2-4 years|                  NaN
# 13               2-4 years|                  NaN
# 14                      NaN                  NaN
# 15             6-12 months|                  NaN
# 16               1-2 years|                  NaN
# 17             6-12 months|                  NaN
# 18                      NaN                  NaN
# 19                      NaN                  NaN
# 20                4+ years|                  NaN
# 21               1-2 years|                  NaN
# 22               2-4 years|                  NaN
# 23                      NaN                  NaN
# 24                      NaN                  NaN
# 25               1-2 years|                  NaN
# 26                      NaN                  NaN
# 27               2-4 years|                  NaN
# 28                      NaN                  NaN
# 29                      NaN                  NaN
# ...                     ...                  ...
# 422976                  NaN  2015-03-25 09:54:51
# 422977                  NaN  2015-03-25 09:54:51
# 422978                  NaN  2015-03-25 09:54:52
# 422979                  NaN  2015-03-25 09:54:52
# 422980                  NaN  2015-03-25 09:54:53
# 422981           1-2 years|  2015-03-25 09:54:53
# 422982  Less than 6 months|  2015-03-25 09:54:54
# 422983                  NaN  2015-03-25 09:54:54
# 422984                  NaN  2015-03-25 09:54:55
# 422985                  NaN  2015-03-25 09:54:55
# 422986                  NaN  2015-03-25 09:54:56
# 422987                  NaN  2015-03-25 09:54:56
# 422988                  NaN  2015-03-25 09:54:57
# 422989                  NaN  2015-03-25 09:54:57
# 422990                  NaN  2015-03-25 09:54:58
# 422991                  NaN  2015-03-25 09:54:58
# 422992                  NaN  2015-03-25 09:54:58
# 422993                  NaN  2015-03-25 09:54:59
# 422994                  NaN  2015-03-25 09:54:59
# 422995                  NaN  2015-03-25 09:55:00
# 422996                  NaN  2015-03-25 09:55:00
# 422997                  NaN  2015-03-25 09:55:00
# 422998                  NaN  2015-03-25 09:55:02
# 422999                  NaN  2015-03-25 09:55:03
# 423000                  NaN  2015-03-25 09:55:04
# 423001                  NaN  2015-03-25 09:55:05
# 423002                  NaN  2015-03-25 09:55:06
# 423003                  NaN  2015-03-25 09:55:07
# 423004         6-12 months|  2015-03-25 09:55:07
# 423005                  NaN  2015-03-25 09:55:08
#
# [423006 rows x 28 columns]

# %%
print('Size of raw csv file:',data.size)
print('Sahe of the raw csv file',data.shape)
print('\n','Raw csv info \n')
data.info()
# Out:
# Size of raw csv file: 11844168
# Sahe of the raw csv file (423006, 28)
#
#  Raw csv info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423006 entries, 0 to 423005
# Data columns (total 28 columns):
# athlete_id            423003 non-null float64
# name                  331110 non-null object
# region                251262 non-null object
# team                  155160 non-null object
# affiliate             241916 non-null object
# gender                331110 non-null object
# age                   331110 non-null float64
# height                159869 non-null float64
# weight                229890 non-null float64
# fran                  55426 non-null float64
# helen                 30279 non-null float64
# grace                 40745 non-null float64
# filthy50              19359 non-null float64
# fgonebad              29738 non-null float64
# run400                22246 non-null float64
# run5k                 36097 non-null float64
# candj                 104435 non-null float64
# snatch                97280 non-null float64
# deadlift              115323 non-null float64
# backsq                110517 non-null float64
# pullups               50608 non-null float64
# eat                   93932 non-null object
# train                 105831 non-null object
# background            98945 non-null object
# experience            104936 non-null object
# schedule              97875 non-null object
# howlong               109206 non-null object
# retrieved_datetime    308945 non-null object
# dtypes: float64(16), object(12)
# memory usage: 90.4+ MB

# %% [markdown]
# ### Romove all NaN rows
# Exploring the csv file you will find many rows with no infomration at all 'NaN' so we can remove them from our data set

# %%
data = data.dropna()

# %%
print('Size of the csv file with NaN removed:',data.size)
print('Sahe of the csv file with NaN removed',data.shape)
print('\n','NaN removed csv info \n')
data.info()
# Out:
# Size of the csv file with NaN removed: 19740
# Sahe of the csv file with NaN removed (705, 28)
#
#  NaN removed csv info
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 34057 to 421423
# Data columns (total 28 columns):
# athlete_id            705 non-null float64
# name                  705 non-null object
# region                705 non-null object
# team                  705 non-null object
# affiliate             705 non-null object
# gender                705 non-null object
# age                   705 non-null float64
# height                705 non-null float64
# weight                705 non-null float64
# fran                  705 non-null float64
# helen                 705 non-null float64
# grace                 705 non-null float64
# filthy50              705 non-null float64
# fgonebad              705 non-null float64
# run400                705 non-null float64
# run5k                 705 non-null float64
# candj                 705 non-null float64
# snatch                705 non-null float64
# deadlift              705 non-null float64
# backsq                705 non-null float64
# pullups               705 non-null float64
# eat                   705 non-null object
# train                 705 non-null object
# background            705 non-null object
# experience            705 non-null object
# schedule              705 non-null object
# howlong               705 non-null object
# retrieved_datetime    705 non-null object
# dtypes: float64(16), object(12)
# memory usage: 159.7+ KB

# %%
data.describe()
# Out:
#           athlete_id         age        height      weight         fran  \
# count     705.000000  705.000000  7.050000e+02  705.000000   705.000000
# mean   107373.651064   33.794326  1.196754e+04  175.523404   338.387234
# std    106231.701769    7.494049  3.159306e+05   30.140294   496.868571
# min      1761.000000   17.000000  3.000000e+00  112.000000    61.000000
# 25%     18441.000000   28.000000  6.600000e+01  150.000000   194.000000
# 50%     96457.000000   33.000000  6.900000e+01  178.000000   258.000000
# 75%    147286.000000   38.000000  7.200000e+01  196.000000   338.000000
# max    580692.000000   56.000000  8.388607e+06  274.000000  5940.000000
#
#               helen          grace       filthy50        fgonebad  \
# count    705.000000     705.000000     705.000000      705.000000
# mean     668.645390    1069.004255    1930.746099     1874.095035
# std      910.643803   18376.504085    8309.613677    37831.873115
# min       60.000000      30.000000      50.000000        0.000000
# 25%      501.000000     138.000000    1222.000000      281.000000
# 50%      564.000000     175.000000    1451.000000      319.000000
# 75%      646.000000     237.000000    1716.000000      363.000000
# max    20827.000000  480480.000000  215400.000000  1000000.000000
#
#               run400         run5k        candj       snatch     deadlift  \
# count     705.000000  7.050000e+02   705.000000   705.000000   705.000000
# mean      549.226950  2.952443e+03   217.994326   168.948936   376.961702
# std     10294.488391  4.029408e+04    90.316237    85.131100   121.009168
# min         4.000000  6.000000e+01   -45.000000     0.000000     0.000000
# 25%        62.000000  1.248000e+03   175.000000   135.000000   305.000000
# 50%        71.000000  1.363000e+03   215.000000   165.000000   385.000000
# 75%        83.000000  1.500000e+03   260.000000   200.000000   445.000000
# max    272220.000000  1.071240e+06  1936.000000  1936.000000  1936.000000
#
#             backsq       pullups
# count   705.000000  7.050000e+02
# mean    303.858156  1.417975e+04
# std     101.821394  3.755900e+05
# min       0.000000 -1.000000e+00
# 25%     235.000000  2.300000e+01
# 50%     305.000000  3.200000e+01
# 75%     365.000000  4.200000e+01
# max    1550.000000  9.972638e+06

# %% [markdown]
# #### Question 1.1
# Generate summary statistics of the data.

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.boxplot(x='age',y='weight', data=data,orient='v')

# %% [markdown]
# #### Question 1.2
# Are the any missing values?  A simple strategy would be to remove rows with missing values. This can however reduce the size of the dataset. Another technique is to imput missing values with a sensible value like the mean.
#
# For more on how to deal with missing values, see this blog entry: [How to Handle Missing Data with Python](https://machinelearningmastery.com/handle-missing-data-python/).

# %% [markdown]
# ### Answer
# Remoed the 'NaN' row's in Question 1 as the data set was to large and was taking up memory

# %% [markdown]
# ### Question 2
#
# Study the `height` column. What distribution does the data follow?
# Hint: Use a histogram or density plot to visualise the data.

# %%
# your answer

# %% [markdown]
# ### Question 3
# What is the average height?

# %%
# your answer

# %% [markdown]
# ### Question 4
#
# Use simple random sampling to sample from the dataset. Choose a sample of 20000.

# %%
# your answer

# %% [markdown]
# ### Question 4
#
# Use stratified sampling to sample from the dataset. Choose a sample of 20000.

# %%
# your answers

# %% [markdown]
# ### Question 5
# Compare simple random sampling and stratified random sampling. Compare the means generated by the two sampling techniques and discuss your observations below your code.

# %% [markdown]
# ### Question 6

# %% [markdown]
# In  this question we are going to implement cluster sampling. Data is divided into clusters, if it isn't already divided into clusters, and then we use simple random sampling to select a number of clusters from the sample. From the group of selected clusters, we again use simple random sampling to select random data points. These now form our sample.
#
# Let's implement this procedure using some randomly generated data that we are going to group into clusters.

# %%
n_clusters = 10
data = stats.norm.rvs(loc=0,        # mean 0
                      scale=1,      # variance 1
                      size=100000,  # number of points
                      random_state=None)

data = pd.DataFrame({'var1': data})  # turn list into dataframe with heading var1

cluster = [rnd.randint(0,9) for c in range(100000)] # generate cluster numbers for grouping

n_col = pd.Series(cluster) # turn list into Series object
data['cluster'] = n_col.values
data.head()

# %% [markdown]
# Now that we've generated random data and placed the data into clusters, generate a sample from the *athletes* data using cluster sampling technique.

# %%
# your answers

# %% [markdown]
# <!-- Distribution fitting with scipy exercise given a dataset. Good references about El Nino dataset. I should find a climate dataset.
#
# https://stackoverflow.com/questions/6615489/fitting-distributions-goodness-of-fit-p-value-is-it-possible-to-do-this-with/16651524#16651524
#
# https://stackoverflow.com/questions/6620471/fitting-empirical-distribution-to-theoretical-ones-with-scipy-python -->
